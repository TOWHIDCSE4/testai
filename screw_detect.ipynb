# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd yolact_colab
# Out:
# /home/aiml/distance_calculation/yolact_colab
# /home/aiml/distance_calculation/distace_calculation/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
! pwd
# Out:
# /home/aiml/distance_calculation/yolact_colab

# %%
# !pip install torch torchvision

# %%
# !python eval.py --trained_model=weights/yolact_base_3333_10000.pth --score_threshold=0.15 --top_k=15 --image=wood_5.jpg:output_image_5.png
# Out:
# Multiple GPUs detected! Turning off JIT.
# Config not specified. Parsed yolact_base_config from the file name.
#
# /home/aiml/distance_calculation/distace_calculation/lib/python3.11/site-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# Loading model.../home/aiml/distance_calculation/yolact_colab/yolact.py:479: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path)
#  Done.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img_path = 'output_image_5.png'  # Path to the saved image

img = mpimg.imread(img_path)
imgplot = plt.imshow(img)
plt.axis('off')  # Hide the axis
plt.show()
